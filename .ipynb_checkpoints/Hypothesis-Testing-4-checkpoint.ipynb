# %%
import pandas as pd
import bamboolib as bam
import plotly.express as px
import numpy as np
from datetime import datetime
import re
bam.enable()
url1 = "https://dshs.texas.gov/coronavirus/TexasCOVID19DailyCountyCaseCountData.xlsx"
url2 = "https://dshs.texas.gov/coronavirus/TexasCOVID-19CumulativeTestsOverTimebyCounty.xlsx"
path1 = "./Rt_no_Rolling.csv"
def getExcel(url, sheet, head):
    df = pd.read_excel(url,sheet_name=sheet, header=head)
    df=df.truncate(before=0,after=253)
    return df

df = getExcel(url1, 'Cases by County', 2)
df.keys()
df2 = df.set_index('County Name')

dftesting  = getExcel(url2, 'Total Tests Received', 1)
dftesting.keys()
dft2 = dftesting.set_index('County')
dft2 = dft2.reset_index()

dfrate = pd.read_csv(path1)

dfrate
# Out:
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'
#     Unnamed: 0  Anderson   Andrews  Angelina   Aransas    Archer  Armstrong  \
# 0     2020/3/5       NaN       NaN       NaN       NaN       NaN        NaN
# 1     2020/3/6       NaN       NaN       NaN       NaN       NaN        NaN
# 2     2020/3/7       NaN       NaN       NaN       NaN       NaN        NaN
# 3     2020/3/8       NaN       NaN       NaN       NaN       NaN        NaN
# 4     2020/3/9       NaN       NaN       NaN       NaN       NaN        NaN
# ..         ...       ...       ...       ...       ...       ...        ...
# 192  2020/9/13  0.320812  1.380490  0.540523  0.406813  0.749298   2.061593
# 193  2020/9/14  0.247374  1.311230  0.894593  0.702409  0.651624   1.823668
# 194  2020/9/15  0.286360  1.007261  0.751476  1.328446  0.535562   0.863449
# 195  2020/9/16  0.348137  0.938159  0.819813  2.008962  0.577297   0.845902
# 196  2020/9/17  0.473343  0.881037  0.895380  1.915822  0.667343   0.885073
#
#      Atascosa    Austin    Bailey  ...   Willacy  Williamson    Wilson  \
# 0         NaN       NaN       NaN  ...       NaN         NaN       NaN
# 1         NaN       NaN       NaN  ...       NaN         NaN       NaN
# 2         NaN       NaN       NaN  ...       NaN         NaN       NaN
# 3         NaN       NaN       NaN  ...       NaN         NaN       NaN
# 4         NaN       NaN       NaN  ...       NaN         NaN       NaN
# ..        ...       ...       ...  ...       ...         ...       ...
# 192  1.148541  1.069032  3.048029  ...  0.252357    1.350874  1.024860
# 193  0.791963  1.457872  4.648033  ...  0.439795    1.525974  0.635398
# 194  0.644106  1.432906  4.140474  ...  0.618158    1.480184  0.385333
# 195  0.352257  1.234989  2.529759  ...  0.860722    1.560723  0.348761
# 196  0.379719  1.421686  1.740825  ...  0.998112    1.435199  0.393660
#
#       Winkler      Wise      Wood    Yoakum     Young    Zapata    Zavala
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 192  1.061591  1.605650  1.420127  1.998175  1.905019  0.182385  0.887911
# 193  0.870760  1.434188  0.879529  2.179665  1.995336  0.278546  0.668338
# 194  0.812385  1.154528  1.141701  1.258516  1.947267  0.392049  0.928686
# 195  0.695975  0.944931  1.172038  1.184990  1.420340  0.535348  0.610823
# 196  0.750929  0.896719  1.177599  0.997157  1.202227  0.726655  0.678961
#
# [197 rows x 252 columns]

# %%
dft3 = dft2.T.copy()
dft3 = dft3.reset_index()
dft3 = dft3.replace('--', np.nan)
dft3 = dft3.replace('-', np.nan)
dft3 = dft3.fillna(method='ffill')

# %%
dft3 = dft3.T.copy()
dft3 = dft3.reset_index()
dft3.columns = [str(column) for column in dft3.columns]
dft3
# Out:
#      index         0                       1                       2  \
# 0    index    County  Tests Through April 21  Tests Through April 22
# 1        0  Anderson                     270                     282
# 2        1   Andrews                       2                       2
# 3        2  Angelina                     282                     311
# 4        3   Aransas                      16                      17
# ..     ...       ...                     ...                     ...
# 250    249      Wood                      75                      81
# 251    250    Yoakum                      14                      14
# 252    251     Young                     311                     322
# 253    252    Zapata                      18                      18
# 254    253    Zavala                      10                      10
#
#                           3                       4                       5  \
# 0    Tests Through April 23  Tests Through April 24  Tests Through April 25
# 1                       297                     329                     337
# 2                         5                       6                       6
# 3                       431                     434                     469
# 4                        15                      24                      27
# ..                      ...                     ...                     ...
# 250                      54                      81                      84
# 251                       2                      11                      12
# 252                      96                     269                     279
# 253                      21                      23                      24
# 254                      13                      15                      13
#
#                           6                       7                       8  \
# 0    Tests Through April 26  Tests Through April 27  Tests Through April 28
# 1                       337                     360                     360
# 2                         6                       6                       6
# 3                       468                     544                     552
# 4                        27                      27                      27
# ..                      ...                     ...                     ...
# 250                      84                      86                      86
# 251                      12                      12                      12
# 252                     279                     286                     286
# 253                      24                      27                      28
# 254                      13                      13                      13
#
#      ...                        136                        137  \
# 0    ...  Tests Through September 3  Tests Through September 4
# 1    ...                      24399                      24446
# 2    ...                       1257                       1261
# 3    ...                      13374                      13483
# 4    ...                       1721                       1738
# ..   ...                        ...                        ...
# 250  ...                       3040                       3092
# 251  ...                        757                        759
# 252  ...                       1856                       1863
# 253  ...                       3091                       3292
# 254  ...                       1687                       1700
#
#                            138                        139  \
# 0    Tests Through September 5  Tests Through September 6
# 1                        24490                      25102
# 2                         1267                       1271
# 3                        13531                      13619
# 4                         1751                       1756
# ..                         ...                        ...
# 250                       3108                       3338
# 251                        765                        773
# 252                       1873                       1879
# 253                       3299                       3301
# 254                       1712                       1726
#
#                            140                        141  \
# 0    Tests Through September 7  Tests Through September 8
# 1                        25291                      25430
# 2                         1281                       1283
# 3                        13658                      13694
# 4                         1815                       1816
# ..                         ...                        ...
# 250                       3372                       3376
# 251                        829                        831
# 252                       1890                       1891
# 253                       3309                       3310
# 254                       1728                       1730
#
#                            142                         143  \
# 0    Tests Through September 9  Tests Through September 10
# 1                        25569                       25569
# 2                         1286                        1286
# 3                        14270                       14275
# 4                         1886                        1895
# ..                         ...                         ...
# 250                       3459                        3459
# 251                        835                         835
# 252                       1899                        1899
# 253                       3317                        3317
# 254                       1740                        1740
#
#                             144                         145
# 0    Tests Through September 11  Tests Through September 12
# 1                         25622                       26253
# 2                          1298                        1308
# 3                         14390                       14895
# 4                          1912                        2011
# ..                          ...                         ...
# 250                        3523                        3903
# 251                         934                         938
# 252                        1907                        1943
# 253                        3361                        3469
# 254                        1770                        1815
#
# [255 rows x 147 columns]

# %%
dft3.shape
# Out:
# (255, 147)
